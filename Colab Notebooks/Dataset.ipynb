# %%
# !npm install -g @openneuro/cli
# Out:
# npm WARN deprecated subscriptions-transport-ws@0.9.19: The `subscriptions-transport-ws` package is no longer maintained. We recommend you use `graphql-ws` instead. For help migrating Apollo software to `graphql-ws`, see https://www.apollographql.com/docs/apollo-server/data/subscriptions/#switching-from-subscriptions-transport-ws    For general help using `graphql-ws`, see https://github.com/enisdenjo/graphql-ws/blob/master/README.md
# npm WARN deprecated async-cache@1.1.0: No longer maintained. Use [lru-cache](http://npm.im/lru-cache) version 7.6 or higher, and provide an asynchronous `fetchMethod` option.
# /tools/node/bin/git-annex-remote-openneuro -> /tools/node/lib/node_modules/@openneuro/cli/src/index.js
# /tools/node/bin/git-credential-openneuro -> /tools/node/lib/node_modules/@openneuro/cli/src/index.js
# /tools/node/bin/openneuro -> /tools/node/lib/node_modules/@openneuro/cli/src/index.js
#
# ...

# %%
# !openneuro download --snapshot 1.0.0 ds003682 drive/MyDrive/data
# Out:
# -----------------------------------------------------
# Your OpenNeuro client is out of date. We strongly recommend you update to the most recent version for an optimal experience.
# -----------------------------------------------------
#
# Skipping present file ".bidsignore"
# Skipping present file "CHANGES"
# Skipping present file "README"
# Skipping present file "dataset_description.json"
# Skipping present file "sub-001/ses-01/meg/sub-001_ses-01_coordsystem.json"
# Skipping present file "sub-001/ses-01/meg/sub-001_ses-01_task-AversiveLearningReplay_run-01_channels.tsv"
# Skipping present file "sub-001/ses-01/meg/sub-001_ses-01_task-AversiveLearningReplay_run-01_events.tsv"
# Skipping present file "sub-001/ses-01/meg/sub-001_ses-01_task-AversiveLearningReplay_run-01_meg.json"
# Skipping present file "sub-001/ses-01/meg/sub-001_ses-01_task-AversiveLearningReplay_run-02_channels.tsv"
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/MyDrive/MT_ML_Decoding/Aversive_state_reactivation/notebooks/templates/load

# %%
# !git clone https://github.com/tobywise/multitask_classification.git drive/MyDrive/MT_ML_Decoding/Aversive_state_reactivation/notebooks/templates/load
# Out:
# Cloning into 'drive/MyDrive/MT_ML_Decoding/Aversive_state_reactivation/notebooks/templates/load'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 17 (delta 3), reused 17 (delta 3), pack-reused 0
# Unpacking objects: 100% (17/17), done.
